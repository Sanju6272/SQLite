# %% [markdown]
# # Count Genre
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the count of each genre present in IMDB movie dataset?
# Print the Genre and number of movies present in that genre.
# Note: Ignore the empty value present in genre.
# Output Format:
# genre_1 num_movie_1
# genre_2 num_movie_2
# . . .
# . . .

# %%
import sqlite3
db=sqlite3.connect('IMDB.sqlite')

# %%
cur=db.cursor()

# %%
cur.execute('Select * from genre')

# %%
for row in cur:
    print(row)
# Out:
# ('36809', 'Biography')
# ('30114', 'Adventure')
# ('37367', 'Comedy')
# ('49473', 'Comedy')
# ('14867', 'Drama')
# ('33832', 'Action')
# ('31722', 'Drama')
# ('25398', 'Drama')
# ('10099', 'Animation')
# ('25281', 'Comedy')
# ('43358', 'Drama')
# ('36798', 'Drama')
# ('10617', 'Drama')
# ('49590', 'Action')
# ('12560', 'Action')
# ('31370', 'Comedy')
# ('48626', 'Biography')
# ('38131', 'Drama')
# ('34191', 'Biography')
# ('20341', 'Action')
# ('18506', 'Action')
# ('38960', 'Animation')
# ('43526', 'Drama')
# ('10015', 'Drama')
# ('11971', 'Drama')
# ('31332', 'Action')
# ('22607', 'Crime')
# ('33884', 'Action')
# ('21508', 'Crime')
# ('30161', 'Drama')
# ('49518', 'Comedy')
# ('12164', 'Action')
# ('13277', 'Crime')
# ('30401', 'Drama')
# ('11289', 'Action')
# ('47403', 'Biography')
# ('21411', 'Adventure')
# ('44738', 'Crime')
# ('21768', 'Drama')
# ('11173', 'Biography')
# ('37652', 'Animation')
# ('48102', 'Animation')
# ('23450', 'Adventure')
# ('23963', 'Adventure')
# ('29611', 'Drama')
# ('46824', 'Action')
# ('42732', 'Animation')
# ('46900', 'Adventure')
# ('45231', 'Action')
# ('47579', 'Action')
# ('26118', 'Animation')
# ('31069', 'Comedy')
# ('41512', 'Drama')
# ('47616', 'Biography')
# ('18458', 'Action')
# ('36478', 'Action')
# ('22767', 'Drama')
# ('30146', 'Comedy')
# ('13316', 'Comedy')
# ('13310', 'Animation')
# ('48554', 'Biography')
# ('29635', 'Adventure')
# ('43350', 'Adventure')
# ('34073', 'Crime')
# ('23417', 'Biography')
# ('12744', 'Biography')
# ('37979', 'Crime')
# ('41592', 'Action')
# ('44253', 'Action')
# ('11928', 'Action')
# ('26438', 'Action')
# ('30154', 'Drama')
# ('36011', 'Mystery')
# ('13627', 'Action')
# ('17294', 'Comedy')
# ('41048', 'Comedy')
# ('47323', 'Action')
# ('28910', 'Crime')
# ('28919', 'Action')
# ('38626', 'Action')
# ('14813', 'Biography')
# ('42419', 'Animation')
# ('34386', 'Comedy')
# ('10454', 'Action')
# ('21538', 'Biography')
# ('39777', 'Drama')
# ('29419', 'Action')
# ('42727', 'Drama')
# ('44160', 'Action')
# ('28130', 'Crime')
# ('22401', 'Adventure')
# ('34429', 'Drama')
# ('41835', 'Adventure')
# ('30250', 'Adventure')
# ('41963', 'Action')
# ('45458', 'Biography')
# ('35832', 'Biography')
# ('47074', 'Animation')
# ('40310', 'Animation')
# ('24887', 'Adventure')
# ('31592', 'Drama')
# ('29441', 'Adventure')
# ('39456', 'Biography')
# ('40287', 'Biography')
# ('32701', 'Crime')
# ('35004', 'Biography')
# ('40832', 'Animation')
# ('44316', 'Adventure')
# ('20420', 'Comedy')
# ('20709', 'Drama')
# ('17545', 'Action')
# ('35939', 'Comedy')
# ('38262', 'Drama')
# ('10023', 'Animation')
# ('27783', 'Action')
# ('42294', 'Action')
# ('32217', 'Animation')
# ('36809', 'Drama')
# ('30114', 'Biography')
# ('37367', 'Drama')
# ('49473', 'Drama')
# ('14867', 'Romance')
# ('33832', 'Biography')
# ('31722', 'Mystery')
# ('25398', 'Romance')
# ('10099', 'Action')
# ('25281', 'Drama')
# ('43358', 'Thriller')
# ('36798', '')
# ('10617', 'History')
# ('49590', 'Adventure')
# ('12560', 'Adventure')
# ('31370', 'Drama')
# ('48626', 'Drama')
# ('38131', 'Sport')
# ('34191', 'Drama')
# ('20341', 'Adventure')
# ('18506', 'Adventure')
# ('38960', 'Adventure')
# ('43526', '')
# ('10015', 'Thriller')
# ('11971', 'Western')
# ('31332', 'Adventure')
# ('22607', 'Drama')
# ('33884', 'Adventure')
# ('21508', 'Drama')
# ('30161', 'Mystery')
# ('49518', 'Drama')
# ('12164', 'Drama')
# ('13277', 'Drama')
# ('30401', 'Sci-Fi')
# ('11289', 'Adventure')
# ('47403', 'Drama')
# ('21411', 'Family')
# ('44738', 'Drama')
# ('21768', 'Romance')
# ('11173', 'Drama')
# ('37652', 'Action')
# ('48102', 'Action')
# ('23450', 'Drama')
# ('23963', 'Comedy')
# ('29611', '')
# ('46824', 'Adventure')
# ('42732', 'Adventure')
# ('46900', 'Drama')
# ('45231', 'Comedy')
# ('47579', 'Adventure')
# ('26118', 'Adventure')
# ('31069', 'Drama')
# ('41512', 'Musical')
# ('47616', 'Drama')
# ('18458', 'Biography')
# ('36478', 'Adventure')
# ('22767', '')
# ('30146', 'Drama')
# ('13316', 'Fantasy')
# ('13310', 'Adventure')
# ('48554', 'Drama')
# ('29635', 'Comedy')
# ('43350', 'Comedy')
# ('34073', 'Drama')
# ('23417', 'Drama')
# ('12744', 'Comedy')
# ('37979', 'Drama')
# ('41592', 'Drama')
# ('44253', 'Adventure')
# ('11928', 'Biography')
# ('26438', 'Comedy')
# ('30154', '')
# ('36011', 'Thriller')
# ('13627', 'Crime')
# ('17294', 'Drama')
# ('41048', 'Drama')
# ('47323', 'Adventure')
# ('28910', 'Drama')
# ('28919', 'Adventure')
# ('38626', 'Adventure')
# ('14813', 'Drama')
# ('42419', 'Adventure')
# ('34386', 'Drama')
# ('10454', 'Sci-Fi')
# ('21538', 'Comedy')
# ('39777', 'War')
# ('29419', 'Thriller')
# ('42727', 'Romance')
# ('44160', 'Biography')
# ('28130', 'Drama')
# ('22401', 'Comedy')
# ('34429', '')
# ('41835', 'Fantasy')
# ('30250', 'Fantasy')
# ('41963', 'Adventure')
# ('45458', 'Drama')
# ('35832', 'Drama')
# ('47074', 'Action')
# ('40310', 'Adventure')
# ('24887', 'Drama')
# ('31592', 'Romance')
# ('29441', 'Drama')
# ('39456', 'Drama')
# ('40287', 'Drama')
# ('32701', 'Drama')
# ('35004', 'Comedy')
# ('40832', 'Adventure')
# ('44316', 'Drama')
# ('20420', 'Horror')
# ('20709', '')
# ('17545', 'Drama')
# ('35939', 'Horror')
# ('38262', 'Music')
# ('10023', 'Adventure')
# ('27783', 'Adventure')
# ('42294', 'Adventure')
# ('32217', 'Adventure')
# ('36809', 'History')
# ('30114', 'Drama')
# ('37367', 'Romance')
# ('49473', 'Fantasy')
# ('14867', '')
# ('33832', 'Drama')
# ('31722', 'Sci-Fi')
# ('25398', '')
# ('10099', 'Adventure')
# ('25281', '')
# ('43358', '')
# ('36798', '')
# ('10617', 'Thriller')
# ('49590', 'Sci-Fi')
# ('12560', 'Sci-Fi')
# ('31370', '')
# ('48626', 'Thriller')
# ('38131', '')
# ('34191', '')
# ('20341', 'Drama')
# ('18506', 'Comedy')
# ('38960', 'Comedy')
# ('43526', '')
# ('10015', '')
# ('11971', '')
# ('31332', 'Fantasy')
# ('22607', '')
# ('33884', 'Sci-Fi')
# ('21508', 'Thriller')
# ('30161', 'Sci-Fi')
# ('49518', 'Romance')
# ('12164', 'War')
# ('13277', 'Mystery')
# ('30401', 'Thriller')
# ('11289', 'Sci-Fi')
# ('47403', 'History')
# ('21411', 'Fantasy')
# ('44738', 'Thriller')
# ('21768', 'Sci-Fi')
# ('11173', 'History')
# ('37652', 'Adventure')
# ('48102', 'Adventure')
# ('23450', 'Family')
# ('23963', 'Drama')
# ('29611', '')
# ('46824', 'Sci-Fi')
# ('42732', 'Comedy')
# ('46900', 'Sci-Fi')
# ('45231', '')
# ('47579', 'Comedy')
# ('26118', 'Family')
# ('31069', 'Music')
# ('41512', 'Romance')
# ('47616', '')
# ('18458', 'Drama')
# ('36478', 'Sci-Fi')
# ('22767', '')
# ('30146', '')
# ('13316', 'Romance')
# ('13310', 'Comedy')
# ('48554', 'Sport')
# ('29635', 'Drama')
# ('43350', 'Drama')
# ('34073', 'Thriller')
# ('23417', '')
# ('12744', 'Drama')
# ('37979', 'Mystery')
# ('41592', 'Sci-Fi')
# ('44253', 'Sci-Fi')
# ('11928', 'Drama')
# ('26438', 'Romance')
# ('30154', '')
# ('36011', '')
# ('13627', 'Drama')
# ('17294', 'Romance')
# ('41048', 'Music')
# ('47323', 'Thriller')
# ('28910', 'History')
# ('28919', 'Sci-Fi')
# ('38626', 'Fantasy')
# ('14813', 'History')
# ('42419', 'Comedy')
# ('34386', 'Romance')
# ('10454', '')
# ('21538', 'Drama')
# ('39777', '')
# ('29419', '')
# ('42727', '')
# ('44160', 'Drama')
# ('28130', 'Mystery')
# ('22401', 'Drama')
# ('34429', '')
# ('41835', '')
# ('30250', '')
# ('41963', 'Mystery')
# ('45458', 'Thriller')
# ('35832', '')
# ('47074', 'Adventure')
# ('40310', 'Drama')
# ('24887', 'Sci-Fi')
# ('31592', '')
# ('29441', 'Thriller')
# ('39456', '')
# ('40287', 'Romance')
# ('32701', 'Thriller')
# ('35004', 'Crime')
# ('40832', 'Comedy')
# ('44316', 'Western')
# ('20420', '')
# ('20709', '')
# ('17545', 'Sport')
# ('35939', '')
# ('38262', '')
# ('10023', 'Comedy')
# ('27783', 'Sci-Fi')
# ('42294', 'Sci-Fi')
# ('32217', 'Comedy')

# %%
cur.execute('Select * from genre')
l=[]
for row in cur:
    l.append(row[1])

# %%
l
# Out:
# ['Biography',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Biography',
#  'Action',
#  'Action',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Crime',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Biography',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Animation',
#  'Animation',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Animation',
#  'Adventure',
#  'Action',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Biography',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Animation',
#  'Biography',
#  'Adventure',
#  'Adventure',
#  'Crime',
#  'Biography',
#  'Biography',
#  'Crime',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Action',
#  'Action',
#  'Biography',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Biography',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Crime',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Biography',
#  'Biography',
#  'Animation',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Biography',
#  'Biography',
#  'Crime',
#  'Biography',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Action',
#  'Action',
#  'Animation',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Biography',
#  'Mystery',
#  'Romance',
#  'Action',
#  'Drama',
#  'Thriller',
#  '',
#  'History',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Sport',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Adventure',
#  '',
#  'Thriller',
#  'Western',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  '',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Musical',
#  'Drama',
#  'Biography',
#  'Adventure',
#  '',
#  'Drama',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Biography',
#  'Comedy',
#  '',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Comedy',
#  'War',
#  'Thriller',
#  'Romance',
#  'Biography',
#  'Drama',
#  'Comedy',
#  '',
#  'Fantasy',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Horror',
#  '',
#  'Drama',
#  'Horror',
#  'Music',
#  'Adventure',
#  'Adventure',
#  'Adventure',
#  'Adventure',
#  'History',
#  'Drama',
#  'Romance',
#  'Fantasy',
#  '',
#  'Drama',
#  'Sci-Fi',
#  '',
#  'Adventure',
#  '',
#  '',
#  '',
#  'Thriller',
#  'Sci-Fi',
#  'Sci-Fi',
#  '',
#  'Thriller',
#  '',
#  '',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  '',
#  '',
#  '',
#  'Fantasy',
#  '',
#  'Sci-Fi',
#  'Thriller',
#  'Sci-Fi',
#  'Romance',
#  'War',
#  'Mystery',
#  'Thriller',
#  'Sci-Fi',
#  'History',
#  'Fantasy',
#  'Thriller',
#  'Sci-Fi',
#  'History',
#  'Adventure',
#  'Adventure',
#  'Family',
#  'Drama',
#  '',
#  'Sci-Fi',
#  'Comedy',
#  'Sci-Fi',
#  '',
#  'Comedy',
#  'Family',
#  'Music',
#  'Romance',
#  '',
#  'Drama',
#  'Sci-Fi',
#  '',
#  '',
#  'Romance',
#  'Comedy',
#  'Sport',
#  'Drama',
#  'Drama',
#  'Thriller',
#  '',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  '',
#  '',
#  'Drama',
#  'Romance',
#  'Music',
#  'Thriller',
#  'History',
#  'Sci-Fi',
#  'Fantasy',
#  'History',
#  'Comedy',
#  'Romance',
#  '',
#  'Drama',
#  '',
#  '',
#  '',
#  'Drama',
#  'Mystery',
#  'Drama',
#  '',
#  '',
#  '',
#  'Mystery',
#  'Thriller',
#  '',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  '',
#  'Thriller',
#  '',
#  'Romance',
#  'Thriller',
#  'Crime',
#  'Comedy',
#  'Western',
#  '',
#  '',
#  'Sport',
#  '',
#  '',
#  'Comedy',
#  'Sci-Fi',
#  'Sci-Fi',
#  'Comedy']

# %%
d={}
for i in l:
    if i in d:
        d[i]+=1
    else:
        d[i]=1

# %%
d
# Out:
# {'Biography': 21,
#  'Adventure': 43,
#  'Comedy': 31,
#  'Drama': 77,
#  'Action': 33,
#  'Animation': 13,
#  'Crime': 11,
#  'Mystery': 7,
#  'Romance': 13,
#  'Thriller': 14,
#  '': 41,
#  'History': 6,
#  'Sport': 3,
#  'Western': 2,
#  'Sci-Fi': 18,
#  'Family': 3,
#  'Musical': 1,
#  'Fantasy': 7,
#  'War': 2,
#  'Horror': 2,
#  'Music': 3}

# %% [markdown]
# # IMDB Movie
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the highest-grossing movie (i.e domestic earning + worldwide earning) in IMDB database.
# Print the rating of that movie.
# Output Format:
# rating

# %%
import pandas as pd
data=pd.read_sql_query('Select * from earning',db)

# %%
data
# Out:
#     Movie_id   Domestic     Worldwide
# 0      36809   56671993  1.877332e+08
# 1      30114   18335230  6.073880e+07
# 2      37367   35014192  3.918778e+07
# 3      49473   15322921  8.710045e+07
# 4      14867    6739492  1.983949e+07
# ..       ...        ...           ...
# 112    38262   13092000  4.898204e+07
# 113    10023  189422889  4.712229e+08
# 114    27783  233921534  7.478628e+08
# 115    42294  146408305  3.536241e+08
# 116    32217  341268248  1.023784e+09
#
# [117 rows x 3 columns]

# %%
data['high-gross']=data['Domestic']+data['Worldwide']

# %%
data
# Out:
#     Movie_id   Domestic     Worldwide    high-gross
# 0      36809   56671993  1.877332e+08  2.444052e+08
# 1      30114   18335230  6.073880e+07  7.907403e+07
# 2      37367   35014192  3.918778e+07  7.420198e+07
# 3      49473   15322921  8.710045e+07  1.024234e+08
# 4      14867    6739492  1.983949e+07  2.657898e+07
# ..       ...        ...           ...           ...
# 112    38262   13092000  4.898204e+07  6.207404e+07
# 113    10023  189422889  4.712229e+08  6.606458e+08
# 114    27783  233921534  7.478628e+08  9.817843e+08
# 115    42294  146408305  3.536241e+08  5.000324e+08
# 116    32217  341268248  1.023784e+09  1.365052e+09
#
# [117 rows x 4 columns]

# %%
high_gross=max(data['high-gross'])

# %%
high_gross
# Out:
# 3004885849.0

# %%
req_data=data[data['high-gross']==high_gross]

# %%
req_data
# Out:
#    Movie_id   Domestic     Worldwide    high-gross
# 79    38626  936662225  2.068224e+09  3.004886e+09

# %%
cur.execute('Select Rating from IMDB where Movie_id=38626')

# %%
cur.fetchall()
# Out:
# [(8.1,)]

# %% [markdown]
# # IMDB voted
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the most voted movie in IMDB Movie Database.
# Print the movie name and the rating of that movie.
# Output Format:
# movie_name rating

# %%
data=pd.read_sql_query('Select * from IMDB',db)

# %%
data
# Out:
#     Movie_id                              Title  Rating  TotalVotes  \
# 0      36809            12 Years a Slave (2013)     8.1      496092
# 1      30114                   127 Hours (2010)     7.6      297075
# 2      37367                       50/50 (2011)     7.7      283935
# 3      49473                  About Time (2013)     7.8      225412
# 4      14867                       Amour (2012)     7.9       76121
# ..       ...                                ...     ...         ...
# 112    38262                    Whiplash (2014)     8.5      492285
# 113    10023              Wreck-It Ralph (2012)     7.7      295125
# 114    27783  X-Men: Days of Future Past (2014)     8.0      560736
# 115    42294          X-Men: First Class (2011)     7.8      556713
# 116    32217                    Zootopia (2016)     8.1      309474
#
#     MetaCritic       Budget  Runtime CVotes10 CVotes09 CVotes08  ...  \
# 0           96   20000000.0  134 min    75556   126223   161460  ...
# 1           82   18000000.0   94 min    28939    44110    98845  ...
# 2           72    8000000.0  100 min    28304    47501    99524  ...
# 3                12000000.0  123 min    38556    43170    70850  ...
# 4           94    8900000.0  127 min    11093    15944    22942  ...
# ..         ...          ...      ...      ...      ...      ...  ...
# 112         88    3300000.0  107 min   110404   161864   132656  ...
# 113         72  165000000.0             41980    50262    96477  ...
# 114         74  200000000.0  132 min    91765   127521   183578  ...
# 115         65  160000000.0  132 min    64428    96219   200144  ...
# 116         78  150000000.0  108 min    53626    70912   102352  ...
#
#     Votes3044 Votes3044M Votes3044F Votes45A Votes45AM Votes45AF VotesIMDB  \
# 0         8.0        7.9        8.0      7.8       7.8       8.1       8.0
# 1         7.5        7.5        7.5      7.3       7.3       7.5       7.6
# 2         7.6        7.6        7.6      7.4       7.4       7.5       7.4
# 3         7.6        7.6        7.7      7.6       7.5       7.8       7.7
# 4         7.7        7.7        7.9      7.9       7.8       8.1       6.6
# ..        ...        ...        ...      ...       ...       ...       ...
# 112       8.3        8.3        8.2      8.1       8.1       8.2       8.7
# 113       7.6        7.6        7.7      7.4       7.4       7.5       7.4
# 114       7.8        7.8        8.0      7.7       7.7       7.9       7.5
# 115       7.7        7.6        7.8      7.6       7.5       7.7       7.6
# 116       7.8        7.8        8.1      7.8       7.8       8.1       7.7
#
#     Votes1000 VotesUS VotesnUS
# 0         7.7     8.3      8.0
# 1         7.0     7.7      7.6
# 2         7.0     7.9      7.6
# 3         6.9     7.8      7.7
# 4         7.2     7.9      7.8
# ..        ...     ...      ...
# 112       8.0     8.6      8.4
# 113       7.2     7.9      7.6
# 114       7.4     8.1      7.9
# 115       7.3     7.8      7.7
# 116       7.6     8.0      8.0
#
# [117 rows x 52 columns]

# %%
high_votes=max(data['TotalVotes'])

# %%
high_votes
# Out:
# 1609713

# %%
req_data=data[data['TotalVotes']==high_votes]

# %%
req_data
# Out:
#    Movie_id             Title  Rating  TotalVotes MetaCritic       Budget  \
# 45    46824  Inception (2010)     8.8     1609713         74  160000000.0
#
#     Runtime CVotes10 CVotes09 CVotes08  ... Votes3044 Votes3044M Votes3044F  \
# 45  148 min   584839   485218   304457  ...       8.7        8.7        8.5
#
#    Votes45A Votes45AM Votes45AF VotesIMDB Votes1000 VotesUS VotesnUS
# 45      8.1       8.1       8.0       8.6       8.2     8.7      8.8
#
# [1 rows x 52 columns]

# %% [markdown]
# # IMDB running time
# IMDB.sqlite database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the Movie with Longest-Running Time from IMDB Movie database.
# Print the name of movie and running time as integer value.
# Note: Don't print 'min' in running time.
# Output Format:
# movie_name running_time

# %%
run_time=data['Runtime']

# %%
run_time
# Out:
# 0      134 min
# 1       94 min
# 2      100 min
# 3      123 min
# 4      127 min
#         ...
# 112    107 min
# 113
# 114    132 min
# 115    132 min
# 116    108 min
# Name: Runtime, Length: 117, dtype: object

# %%
import numpy as np
l=[]
for i in range(117):
    l.append(run_time.values[i][:3])

# %%
l
# Out:
# ['134',
#  '94 ',
#  '100',
#  '123',
#  '127',
#  '120',
#  '116',
#  '109',
#  '',
#  '119',
#  '108',
#  '165',
#  '142',
#  '147',
#  '136',
#  '',
#  '134',
#  '133',
#  '117',
#  '130',
#  '108',
#  '',
#  '',
#  '115',
#  '165',
#  '115',
#  '100',
#  '113',
#  '109',
#  '108',
#  '',
#  '134',
#  '149',
#  '91 ',
#  '121',
#  '139',
#  '146',
#  '102',
#  '126',
#  '127',
#  '',
#  '',
#  '126',
#  '',
#  '',
#  '148',
#  '95 ',
#  '169',
#  '117',
#  '129',
#  '',
#  '128',
#  '158',
#  '118',
#  '121',
#  '120',
#  '137',
#  '105',
#  '',
#  '',
#  '133',
#  '94 ',
#  '115',
#  '118',
#  '98 ',
#  '',
#  '153',
#  '',
#  '133',
#  '123',
#  '112',
#  '',
#  '138',
#  '121',
#  '122',
#  '',
#  '143',
#  '128',
#  '132',
#  '136',
#  '147',
#  '',
#  '100',
#  '143',
#  '130',
#  '131',
#  '164',
#  '126',
#  '116',
#  '158',
#  '99 ',
#  '146',
#  '169',
#  '161',
#  '146',
#  '114',
#  '118',
#  '100',
#  '108',
#  '144',
#  '102',
#  '156',
#  '120',
#  '123',
#  '125',
#  '180',
#  '103',
#  '110',
#  '',
#  '',
#  '140',
#  '',
#  '107',
#  '',
#  '132',
#  '132',
#  '108']

# %%
np_l=np.array(l)

# %%
np_l[np_l=='']='0.0'

# %%
np_l
# Out:
# array(['134', '94 ', '100', '123', '127', '120', '116', '109', '119',
#        '108', '165', '142', '147', '136', '134', '133', '117', '130',
#        '108', '0.0', '115', '165', '115', '100', '113', '109', '108',
#        '134', '149', '91 ', '121', '139', '146', '102', '126', '127',
#        '0.0', '126', '0.0', '148', '95 ', '169', '117', '129', '128',
#        '158', '118', '121', '120', '137', '105', '0.0', '133', '94 ',
#        '115', '118', '98 ', '153', '133', '123', '112', '138', '121',
#        '122', '143', '128', '132', '136', '147', '100', '143', '130',
#        '131', '164', '126', '116', '158', '99 ', '146', '169', '161',
#        '146', '114', '118', '100', '108', '144', '102', '156', '120',
#        '123', '125', '180', '103', '110', '0.0', '140', '107', '132',
#        '132', '108'], dtype='<U3')

# %%
np_l=np.array(np_l,dtype=float)

# %%
max_run=np.max(np_l)

# %%
max_run
# Out:
# 180.0

# %%
max_run='180 min'

# %%
req_data=data[data['Runtime']==max_run]

# %%
req_data
# Out:
#     Movie_id                           Title  Rating  TotalVotes MetaCritic  \
# 105    35004  The Wolf of Wall Street (2013)     8.2      881984         75
#
#           Budget  Runtime CVotes10 CVotes09 CVotes08  ... Votes3044  \
# 105  100000000.0  180 min   171660   236650   250667  ...       8.0
#
#     Votes3044M Votes3044F Votes45A Votes45AM Votes45AF VotesIMDB Votes1000  \
# 105        8.1        7.7      7.6       7.6       7.5       7.8       7.8
#
#     VotesUS VotesnUS
# 105     8.1      8.1
#
# [1 rows x 52 columns]

# %% [markdown]
# # IMDB profit
# IMDB.sqlite database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the movie which has maximum net profit in IMDB Movie Database.
# Print the movie name.
# Note: Net Profit= Total Earning(Domestic+WorldWide earning) - budget
# Output Format:
# movie_name

# %%
import pandas as pd
import numpy as np
import sqlite3
db=sqlite3.connect('IMDB.sqlite')
imdb=pd.read_sql_query('Select * from IMDB',db)
earning=pd.read_sql_query('Select * from earning',db)
genre=pd.read_sql_query('Select * from genre',db)

index=imdb[imdb['Budget']==''].index
imdb.drop(index,inplace=True)
earning['Total Earning']=earning['Domestic']+earning['Worldwide']
result=pd.merge(imdb,earning,on='Movie_id')
result['Profit']=result['Total Earning']-result['Budget']
movie_name=result[result['Profit']==max(result['Profit'])].values[0]
print(movie_name[1])
# Out:
# Star Wars: The Force Awakens (2015)

# %% [markdown]
# # IMDB least budget
# IMDB.sqlite database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the least budgeted movie in IMDB Movie Database.
# If there is more than one least budgeted movies then print the movie which has maximum net profit.
# Note: Net Profit= Total Earning(Domestic+WorldWide earning) - budget
# Output Format:
# movie_name

# %%
import pandas as pd
import numpy as np
import sqlite3
db=sqlite3.connect('IMDB.sqlite')
imdb=pd.read_sql_query('Select * from IMDB',db)
earning=pd.read_sql_query('Select * from earning',db)
genre=pd.read_sql_query('Select * from genre',db)

# %%
imdb_earning=pd.merge(imdb,earning,on='Movie_id')

# %%
imdb_earning['Domestic'].replace('',0,inplace=True)
imdb_earning['Worldwide'].replace('',0,inplace=True)

# %%
imdb_earning['Total Earning']=imdb_earning['Domestic']+imdb_earning['Worldwide']

# %%
imdb_earning['Budget'].replace('',0,inplace=True)
least_budget=imdb_earning[imdb_earning['Budget']==sorted(imdb_earning['Budget'].values)[3]].values

# %%
profit_1_movie=least_budget[0][54]-least_budget[0][5]
profit_2_movie=least_budget[1][54]-least_budget[1][5]

# %%
if profit_1_movie > profit_2_movie:
    print(least_budget[0][1])
else:
    print(least_budget[1][1])
# Out:
# Short Term 12 (2013)

# %% [markdown]
# # IMDB Year Top
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the highest-grossing movie (i.e domestic earning + worldwide earning) in IMDB database year wise.
# Print the Year and name of the movie which was the highest grosser in that year.
# Note:Print the year in ascending order.
# Output Format:
# year_1 name_movie_1
# year_2 name_movie_2
# year_3 name_movie_3
# . . .
# . . .

# %%
import pandas as pd
import numpy as np
import sqlite3

db = sqlite3.connect('IMDB.sqlite')
data = pd.read_sql_query('select * from earning join IMDB using(Movie_id)',db)

data['Total'] = data['Domestic'] + data['Worldwide']

def year(title):
    return int(title.strip().split(" ")[-1][-5:-1])

data['Year'] = data["Title"].apply(year)
data['Year'].unique()

m = data.groupby('Year')['Total'].max()

d = {}
for i in range(len(data['Total'])):
    if data['Total'][i] in (m.values):
        key = data['Year'][i]
        value = data['Title'][i]
        d[key] = value
        
for i  in sorted(d):
    print(i,d[i])
# Out:
# 2010 Toy Story 3 (2010)
# 2011 Rise of the Planet of the Apes (2011)
# 2012 The Avengers (2012)
# 2013 The Hunger Games: Catching Fire (2013)
# 2014 Guardians of the Galaxy (2014)
# 2015 Star Wars: The Force Awakens (2015)
# 2016 Rogue One (2016)

# %% [markdown]
# # IMDB genre budget
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find out the percentage of the budget for each genre in IMDB Movie Dataset?Plot the pie chart.
# Print the genre and percentage of movies budget present in that genre with 2 decimal place after rounding off..
# Note: Movies has multiple genres, so calculate the percentage for each genre.Replace empty budget column to zero.
# Output Format:
# genre_1 percent_1
# genre_2 percent_2
# . . .
# . . .

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

db=sqlite3.connect('IMDB.sqlite')
data=pd.read_sql_query('select movie_id,genre from genre',db)
data2=pd.read_sql_query('select movie_id,Budget from IMDB',db)
data2[data2.Budget=='']='0.0'
gen=np.array(data)
arr=np.array(data2)
m={}
total=0
for i in range(0,gen.shape[0]):
    for j in range(0,arr.shape[0]):
        if(gen[i][0]==arr[j][0]):
            curg=gen[i][1]
            m[curg]=m.get(curg,0)+float(arr[j][1])

data = pd.read_sql_query('select genre,sum(budget) from IMDB inner join genre on IMDB.movie_id=Genre.movie_id group by genre',db)
total = sum(data['sum(budget)'])
total = total - data['sum(budget)'][0]
for i in m:
    if(i!=''):
        print(i," ","{0:.2f}".format(round((m[i]*100)/total,2)))
# Out:
# Biography   2.59
# Adventure   25.10
# Comedy   7.22
# Drama   10.85
# Action   17.98
# Animation   7.66
# Crime   1.77
# Mystery   1.95
# Romance   1.12
# Thriller   3.99
# History   0.72
# Sport   0.46
# Western   0.57
# Sci-Fi   10.77
# Family   1.91
# Musical   0.25
# Fantasy   4.54
# War   0.36
# Horror   0.03
# Music   0.15

# %% [markdown]
# # IMDB genre earning
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find out the percentage of the total earning for each genre in IMDB Movie Dataset?Plot the pie chart.
# Print the genre and percentage of movies total earning present in that genre with 2 decimal place after rounding off.
# Note: Movies has multiple genres, so calculate the percentage for each genre.Total Earning=Domestic earning + WorldWide earning.
# Output Format:
# genre_1 percent_1
# genre_2 percent_2
# . . .
# . . .

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

db = sqlite3.connect('IMDB.sqlite')

data = pd.read_sql_query('Select * from genre join earning using(Movie_id)',db)

data['Total'] = data["Domestic"] + data["Worldwide"]
data['Total'].unique()
data["genre"].replace("",np.NaN,inplace=True)
data.dropna(subset=["genre"],inplace=True)

grouped_sum=data.groupby("genre")['Total'].sum()

percent = np.true_divide(grouped_sum,grouped_sum.sum())*100
for i in range(len(grouped_sum)):
    print(grouped_sum.index[i],format(percent[i],".2f"))

plt.pie(grouped_sum,labels=grouped_sum.index,autopct="%.2f")
plt.show()
# Out:
# Action 17.91
# Adventure 23.57
# Animation 6.77
# Biography 3.42
# Comedy 7.69
# Crime 1.55
# Drama 11.96
# Family 1.05
# Fantasy 5.15
# History 1.04
# Horror 0.01
# Music 0.43
# Musical 0.38
# Mystery 2.01
# Romance 1.45
# Sci-Fi 9.95
# Sport 0.32
# Thriller 4.42
# War 0.25
# Western 0.65

# %% [markdown]
# # IMDB Specific Genre
# IMDB.sqlite' database contains all details of movies and has three tables with name IMDB, genre and earning.
# Find the movie which has genre of 'Sci-Fi' and 'Mystery' and movie rating is greater or equal to 8 from IMDB Movie Database.
# Print the movie name.
# Movies has multiple genre.
# Output Format:
# movie_name

# %%
import sqlite3
import pandas as pd

db=sqlite3.connect('IMDB.sqlite')

data=pd.read_sql_query('Select * from IMDB join genre using (Movie_id)',db)
data
# Out:
#     Movie_id                      Title  Rating  TotalVotes MetaCritic  \
# 0      36809    12 Years a Slave (2013)     8.1      496092         96
# 1      36809    12 Years a Slave (2013)     8.1      496092         96
# 2      36809    12 Years a Slave (2013)     8.1      496092         96
# 3      30114           127 Hours (2010)     7.6      297075         82
# 4      30114           127 Hours (2010)     7.6      297075         82
# ..       ...                        ...     ...         ...        ...
# 346    42294  X-Men: First Class (2011)     7.8      556713         65
# 347    42294  X-Men: First Class (2011)     7.8      556713         65
# 348    32217            Zootopia (2016)     8.1      309474         78
# 349    32217            Zootopia (2016)     8.1      309474         78
# 350    32217            Zootopia (2016)     8.1      309474         78
#
#           Budget  Runtime CVotes10 CVotes09 CVotes08  ... Votes3044M  \
# 0     20000000.0  134 min    75556   126223   161460  ...        7.9
# 1     20000000.0  134 min    75556   126223   161460  ...        7.9
# 2     20000000.0  134 min    75556   126223   161460  ...        7.9
# 3     18000000.0   94 min    28939    44110    98845  ...        7.5
# 4     18000000.0   94 min    28939    44110    98845  ...        7.5
# ..           ...      ...      ...      ...      ...  ...        ...
# 346  160000000.0  132 min    64428    96219   200144  ...        7.6
# 347  160000000.0  132 min    64428    96219   200144  ...        7.6
# 348  150000000.0  108 min    53626    70912   102352  ...        7.8
# 349  150000000.0  108 min    53626    70912   102352  ...        7.8
# 350  150000000.0  108 min    53626    70912   102352  ...        7.8
#
#     Votes3044F Votes45A Votes45AM Votes45AF VotesIMDB Votes1000 VotesUS  \
# 0          8.0      7.8       7.8       8.1       8.0       7.7     8.3
# 1          8.0      7.8       7.8       8.1       8.0       7.7     8.3
# 2          8.0      7.8       7.8       8.1       8.0       7.7     8.3
# 3          7.5      7.3       7.3       7.5       7.6       7.0     7.7
# 4          7.5      7.3       7.3       7.5       7.6       7.0     7.7
# ..         ...      ...       ...       ...       ...       ...     ...
# 346        7.8      7.6       7.5       7.7       7.6       7.3     7.8
# 347        7.8      7.6       7.5       7.7       7.6       7.3     7.8
# 348        8.1      7.8       7.8       8.1       7.7       7.6     8.0
# 349        8.1      7.8       7.8       8.1       7.7       7.6     8.0
# 350        8.1      7.8       7.8       8.1       7.7       7.6     8.0
#
#     VotesnUS      genre
# 0        8.0  Biography
# 1        8.0      Drama
# 2        8.0    History
# 3        7.6  Adventure
# 4        7.6  Biography
# ..       ...        ...
# 346      7.7  Adventure
# 347      7.7     Sci-Fi
# 348      8.0  Adventure
# 349      8.0  Animation
# 350      8.0     Comedy
#
# [351 rows x 53 columns]

# %%
data = data[((data["genre"]=='Sci-Fi') & (data["Rating"]>=8)) | ((data["genre"]=='Mystery') & (data["Rating"]>=8))]

# %%
data['Title'].values[0]
# Out:
# 'Arrival\xa0(2016)'
